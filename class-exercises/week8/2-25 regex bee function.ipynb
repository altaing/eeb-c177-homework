# %% [markdown]
# 1. convert file to CSV and load in file (skipping first row)
# 2. separate authors (by column?)
#     3. split at ',' and '&'
#     4. remove parenthesses
#     5. remove numbers
# 6. count

# %%
import csv
import re
auth = []
with open('bee_list.txt', 'r') as bee:
    data = csv.DictReader(bee, delimiter='\t')
    header = data.fieldnames
    for row in data:
        auth.append(row['Taxon Author'])
auth
# Out:
# ['Michener, 1986',
#  '(Cockerell, 1934)',
#  '(Timberlake, 1951)',
#  '(Timberlake, 1951)',
#  'Zavortink, 1994',
#  'Zavortink, 1974',
#  'Dours, 1873',
#  'Eversmann, 1852',
#  'Pérez, 1895',
#  '(Cockerell, 1922)',
#  'Warncke, 1967',
#  'Hirashima, 1962',
#  'Viereck, 1916',
#  'Warncke, 1967',
#  'Morawitz, 1886',
#  'Warncke, 1967',
#  'LaBerge, 1980',
#  'Morawitz, 1876',
#  'Morawitz, 1876',
#  'Friese, 1899',
#  'Friese, 1922',
#  'Morawitz, 1872',
#  'LaBerge, 1967',
#  'Dours, 1873',
#  'LaBerge, 1967',
#  'Warncke, 1974',
#  'Warncke, 1974',
#  'LaBerge, 1967',
#  'Warncke, 1967',
#  'Friese, 1909',
#  'Smith, 1879',
#  '(Scopoli, 1770)',
#  'Warncke, 1967',
#  'Thorp, 1969',
#  'Morawitz, 1876',
#  'Osytshnjuk, 1993',
#  'Osytshnjuk, 1993',
#  'Tadauchi, Hirashima & Matsumura, 1987',
#  'Tadauchi & Hirashima, 1984',
#  'Viereck, 1917',
#  'Popov, 1949',
#  'Hirashima, 1966',
#  'Viereck, 1917',
#  'Alfken, 1927',
#  'Radoszkowski, 1874',
#  '(Rossi, 1792)',
#  '(Viereck, 1904)',
#  'LaBerge, 1986',
#  'Warncke, 1974',
#  'Perkins, 1914',
#  'Warncke, 1965',
#  'Smith, 1853',
#  'Robertson, 1891',
#  'Cockerell, 1897',
#  'Osytshnjuk, 1986',
#  'Viereck, 1907',
#  'Warncke, 1975',
#  'Benoist, 1961',
#  'Tadauchi, Miyanaga & Dawut, 2005',
#  'Lebedev, 1932',
#  'Stoeckhert, 1942',
#  'Hirashima, 1960',
#  'Cockerell, 1949',
#  'Warncke, 1967',
#  'Morawitz, 1876',
#  '(Viereck, 1904)',
#  'Warncke, 1967',
#  'Alfken, 1935',
#  'Linsley & MacSwain, 1961',
#  '(Cresson, 1878)',
#  'Cockerell, 1929',
#  'Timberlake, 1951',
#  'Cockerell, 1936',
#  'LaBerge, 1971',
#  'Viereck, 1904',
#  '(Kirby, 1802)',
#  'Viereck, 1904',
#  'Cockerell, 1936',
#  'Tadauchi & Matsumura, 2007',
#  'Ribble, 1968',
#  'Cockerell, 1901',
#  'Cameron, 1897',
#  'Morawitz, 1880',
#  'Blüthgen, 1925',
#  'Pérez, 1895',
#  'Viereck & Cockerell, 1914',
#  'Tadauchi & Hirashima, 1987',
#  'Cockerell, 1897',
#  'Linsley & MacSwain, 1961',
#  'Smith, 1847',
#  'Kreichbaumer, 1873',
#  'LaBerge, 1971',
#  'Scheuchl & Gusenleitner, 2007',
#  'Robertson, 1897',
#  'Ribble, 1968',
#  'LaBerge, 1967',
#  'Osytshnjuk, 1983',
#  'LaBerge & Ribble, 1972',
#  'Cockerell, 1896',
#  'Smith, 1844',
#  'Viereck, 1917',
#  'Schmiedeknecht, 1900',
#  'Cameron, 1909',
#  'Popov, 1940',
#  'Schmiedeknecht, 1900',
#  'Warncke, 1967',
#  'Friese, 1921',
#  'Pérez, 1895',
#  'Pérez, 1895',
#  'Osytshnjuk, 1977',
#  'Radoszkowski, 1876',
#  'Robertson, 1891',
#  'Mitchell, 1960',
#  'Warncke, 1967',
#  'Viereck & Cockerell, 1914',
#  'Warncke, 1975',
#  'Warncke, 1965',
#  'Mitchell, 1960',
#  'Friese, 1887',
#  'Morawitz, 1894',
#  'Hedicke, 1923',
#  '(Cockerell, 1941)',
#  'Smith, 1879',
#  'Xu & Tadauchi, 2006',
#  'Donovan, 1977',
#  'LaBerge, 1967',
#  'Tadauchi & Hirashima, 1983',
#  'Viereck & Cockerell, 1914',
#  'Warncke, 1967',
#  'LaBerge & Ribble, 1972',
#  'Lebedev, 1932',
#  'Tadauchi & Hirashima, 1987',
#  'Timberlake, 1941',
#  'Morawitz, 1876',
#  'LaBerge, 1967',
#  'Nurse, 1904',
#  'Viereck, 1924',
#  'Malloch, 1917',
#  'Bouseman & LaBerge, 1979',
#  'Panzer, 1805',
#  'Cockerell, 1898',
#  '(Kirby, 1802)',
#  'Cockerell, 1930',
#  'Alfken, 1929',
#  'Warncke, 1969',
#  'Xu, 1994',
#  'Warncke, 1975',
#  'LaBerge, 1967',
#  'Xu, 1994',
#  'Pérez, 1895',
#  'LaBerge, 1968',
#  'Donovan, 1977',
#  'Hirashima, 1962',
#  'Schulthess, 1924',
#  'Cockerell, 1917',
#  'Cockerell, 1905',
#  'Viereck & Cockerell, 1914',
#  'Linsley, 1938',
#  'Warncke, 1975',
#  'LaBerge, 1971',
#  'Warncke, 1975',
#  'Morawitz, 1876',
#  'Fabricius, 1775',
#  '(Rossi, 1790)',
#  'Nurse, 1904',
#  'Warncke, 1967',
#  'Friese, 1923',
#  'Osytshnjuk, 1994',
#  'LaBerge, 1967',
#  '(Kirby, 1802)',
#  'Smith, 1853',
#  'Cockerell, 1901',
#  'Viereck, 1908',
#  'Viereck, 1917',
#  'Pérez, 1895',
#  'Morawitz, 1877',
#  'Cockerell, 1924',
#  'Pérez, 1895',
#  'Thorp, 1969',
#  'Donovan, 1977',
#  'Warncke, 1969',
#  'Osytshnjuk, 1984',
#  'Linsley & MacSwain, 1962',
#  'Dours, 1872',
#  'Viereck, 1907',
#  'Viereck, 1907',
#  'Vachal, 1901',
#  'Friese, 1887',
#  'Bouseman & LaBerge, 1979',
#  'Hirashima, 1962',
#  'Cockerell, 1930',
#  'Pérez, 1895',
#  'Larkin, 2004',
#  'Friese, 1899',
#  'Viereck & Cockerell, 1914',
#  'LaBerge, 1971',
#  'LaBerge & Ribble, 1972',
#  'Stephens, 1846',
#  'Viereck, 1924',
#  'Warncke, 1965',
#  'LaBerge, 1967',
#  'Bingham, 1908',
#  'Warncke, 1965',
#  'Schmiedeknecht, 1900',
#  'Warncke, 1969',
#  'Smith, 1879',
#  'Viereck, 1926',
#  'Warncke, 1974',
#  'Warncke, 1975',
#  'Ribble, 1968',
#  'Viereck, 1916',
#  'Cockerell, 1929',
#  'Warncke, 1967',
#  'LaBerge, 1967',
#  'Wu, 1977',
#  'Linsley & MacSwain, 1968',
#  'Dalla Torre, 1896',
#  'Smith, 1879',
#  'Viereck & Cockerell, 1914',
#  'Strand, 1915',
#  'Strand, 1915',
#  '(Friese, 1923)',
#  'Warncke, 1975',
#  'Warncke, 1975',
#  'Morawitz, 1876',
#  'Osytshnjuk, 1986',
#  'Casad & Cockerell, 1896',
#  'Warncke, 1975',
#  'Nurse, 1904',
#  'Pérez, 1902',
#  'Morawitz, 1877',
#  'Morawitz, 1876',
#  'Wu, 1982',
#  'Cockerell, 1901',
#  'Pérez, 1895',
#  'Viereck, 1909',
#  'Mitchell, 1960',
#  'Cockerell, 1896',
#  'Morawitz, 1886',
#  'Warncke, 1975',
#  'Warncke, 1965',
#  'Viereck, 1917',
#  'Linsley, 1938',
#  'Xu, 1994',
#  'Cockerell, 1896',
#  'Cockerell, 1936',
#  'Mitchell, 1960',
#  'Warncke, 1975',
#  'Pittioni, 1950',
#  'Brullé, 1839',
#  '(Cresson, 1878)',
#  '(Viereck, 1904)',
#  'Neff & Larkin, 2002',
#  'Viereck, 1904',
#  'Wu, 1977',
#  'Warncke, 1975',
#  'Yasumatsu, 1935',
#  'Dubitzky, 2006',
#  'Warncke, 1972',
#  'Viereck & Cockerell, 1914',
#  'Cockerell, 1917',
#  'Mitchell, 1960',
#  'Tadauchi, 1992',
#  'Viereck, 1904',
#  'Linsley & MacSwain, 1961',
#  'Cockerell, 1916',
#  'Dubitzky, 2006',
#  'Cockerell, 1899',
#  'Baker, 1995',
#  'Pérez, 1903',
#  'Schenck, 1853',
#  '(Kirby, 1802)',
#  'Linsley & MacSwain, 1961',
#  'Warncke, 1975',
#  '(Linnaeus, 1758)',
#  'Brullé, 1832',
#  'Warncke, 1965',
#  'Warncke, 1975',
#  'Viereck, 1917',
#  '(Kirby, 1802)',
#  '(Viereck, 1904)',
#  'Warncke, 1966',
#  'Strand, 1921',
#  'Viereck, 1917',
#  'Lebedev, 1933',
#  'LaBerge, 1980',
#  '(Kirby, 1802)',
#  'Nurse, 1904',
#  'Morawitz, 1874',
#  'Cockerell, 1906',
#  'Morawitz, 1886',
#  'Viereck, 1917',
#  'Warncke, 1966',
#  '(Christ, 1791)',
#  'Morawitz, 1876',
#  'Smith, 1879',
#  'Smith, 1879',
#  'Thorp & LaBerge, 2005',
#  'Lepeletier, 1841',
#  'Gusenleitner & Schwarz, 2000',
#  'Eversmann, 1852',
#  'Smith, 1853',
#  '(Cockerell, 1898)',
#  'Viereck, 1917',
#  'LaBerge, 1977',
#  'Schmiedeknecht, 1884',
#  'LaBerge & Bouseman, 1970',
#  'Warncke, 1967',
#  'Morawitz, 1877',
#  'Viereck, 1907',
#  'Warncke, 1975',
#  'Theunert, 2006',
#  'LaBerge, 1977',
#  'Viereck & Cockerell, 1914',
#  'Cockerell, 1899',
#  'Warncke, 1965',
#  'Cockerell, 1931',
#  'Robertson, 1893',
#  'Viereck, 1909',
#  'Pérez, 1895',
#  'Warncke, 1965',
#  'Robertson, 1891',
#  'Bouseman & LaBerge, 1979',
#  'Warncke, 1975',
#  'Viereck, 1917',
#  'Mitchell, 1960',
#  'Ribble, 1974',
#  'LaBerge, 1971',
#  'Timberlake, 1951',
#  'Cockerell, 1922',
#  'Friese, 1914',
#  'Warncke, 1975',
#  'Warncke, 1974',
#  'Viereck, 1926',
#  'Cockerell, 1901',
#  '(Morawitz, 1877)',
#  'Morice, 1899',
#  'Pérez, 1903',
#  'Warncke, 1965',
#  'Thomson, 1870',
#  'Morawitz, 1886',
#  'Pérez, 1895',
#  'Cockerell, 1906',
#  '(Cockerell, 1916)',
#  'Gribodo, 1894',
#  'LaBerge, 1987',
#  'Pittioni, 1950',
#  'Mavromoustakis, 1952',
#  'Viereck, 1907',
#  'Cockerell, 1910',
#  'Warncke, 1968',
#  'Warncke, 1974',
#  'LaBerge, 1971',
#  'Warncke, 1965',
#  'Warncke, 1969',
#  'Viereck & Cockerell, 1914',
#  'Viereck, 1907',
#  'Warncke, 1967',
#  'Schenck, 1861',
#  'LaBerge, 1977',
#  'Warncke, 1974',
#  'LaBerge & Thorp, 2005',
#  'Cockerell, 1918',
#  'Warncke, 1965',
#  'Smith, 1879',
#  '(Kirby, 1802)',
#  'Morawitz, 1874',
#  'Cockerell, 1910',
#  'Morawitz, 1886',
#  'Warncke, 1974',
#  'Timberlake, 1937',
#  'Gusenleitner, 1998',
#  'Mitchell, 1960',
#  'Warncke, 1975',
#  'Morawitz, 1876',
#  'Erichson, 1841',
#  'Smith, 1879',
#  'Timberlake, 1951',
#  'Thorp & LaBerge, 2005',
#  'Provancher, 1888',
#  'Schenck, 1871',
#  'Pérez, 1895',
#  'Osytshnjuk, 1993',
#  'Tadauchi & Xu, 1997',
#  'Osytshnjuk, 1979',
#  'Lanham, 1949',
#  'Morawitz, 1894',
#  'Brullé, 1832',
#  '(Kirby, 1802)',
#  'Dufour, 1853',
#  'LaBerge, 1967',
#  'Kohl, 1905',
#  'Timberlake, 1951',
#  'Cockerell, 1898',
#  'Mitchell, 1960',
#  'Viereck & Cockerell, 1914',
#  'Popov, 1949',
#  'Lebedev, 1929',
#  'Hirashima & Haneda, 1973',
#  'Hirashima, 1960',
#  'Gusenleitner, 1998',
#  'Viereck, 1916',
#  'Morawitz, 1888',
#  'Warncke, 1975',
#  'Giraud, 1863',
#  'Gusenleitner, 1998',
#  'Grünwaldt & Osytshnjuk, 2005',
#  'Cockerell, 1914',
#  'Gusenleitner, 1998',
#  'Viereck, 1917',
#  'Wu, 1982',
#  '(Cockerell, 1898)',
#  'Stoeckhert, 1924',
#  'Popov, 1949',
#  'Linsley & MacSwain, 1961',
#  'Morawitz, 1871',
#  'Thorp & LaBerge, 2005',
#  'Guiglia, 1933',
#  'Robertson, 1891',
#  'Osytshnjuk, 1984',
#  '(Ashmead, 1890)',
#  'Robertson, 1891',
#  'Hirashima, 1957',
#  'Cockerell, 1938',
#  'Scheuchl, 2005',
#  'Pérez, 1895',
#  'Warncke, 1974',
#  'Radoszkowski, 1867',
#  'Linsley & MacSwain, 1961',
#  'Viereck, 1924',
#  'Erichson, 1835',
#  'Warncke, 1975',
#  'Hirashima, 1965',
#  'Warncke, 1966',
#  'Pérez, 1903',
#  'LaBerge, 1987',
#  'Xu & Tadauchi, 2005',
#  'Warncke, 1969',
#  'Perkins, 1915',
#  'Hirashima, 1966',
#  'Smith, 1878',
#  'Xu & Tadauchi, 2000',
#  'Pérez, 1895',
#  'Smith, 1879',
#  'Morawitz, 1876',
#  'Viereck, 1922',
#  'Morawitz, 1876',
#  'Smith, 1847',
#  'Dours, 1872',
#  'LaBerge, 1977',
#  'Pérez, 1895',
#  'Pérez, 1895',
#  'Morawitz, 1866',
#  'Brullé, 1832',
#  'Scheuchl, 2004',
#  'Popov, 1949',
#  'Nurse, 1904',
#  'LaBerge, 1971',
#  'Timberlake, 1937',
#  'Panzer, 1799',
#  'Morawitz, 1876',
#  'Warncke, 1965',
#  'Nurse, 1904',
#  'Xu & Tadauchi, 2000',
#  'Malloch, 1917',
#  'LaBerge & Ribble, 1972',
#  'Fabricius, 1793',
#  'Magretti, 1883',
#  'Eversmann, 1852',
#  'Smith, 1878',
#  'Eversmann, 1852',
#  'Robertson, 1891',
#  'Cockerell, 1911',
#  'Osytshnjuk, 1978',
#  'Hedicke, 1940',
#  'Alfken, 1932',
#  'Cockerell, 1898',
#  'Casad & Cockerell, 1896',
#  'Smith, 1853',
#  'Warncke, 1975',
#  'Alfken, 1904',
#  'Warncke, 1975',
#  'Smith, 1853',
#  'Smith, 1847',
#  'Cockerell, 1914',
#  'Hirashima, 1952',
#  'LaBerge, 1980',
#  'Warncke, 1974',
#  'Pérez, 1895',
#  'Warncke, 1965',
#  'LaBerge, 1967',
#  'LaBerge, 1967',
#  '(Müller, 1766)',
#  '(Christ, 1791)',
#  'Stoeckhert, 1930',
#  'Viereck, 1924',
#  'Schenck, 1853',
#  'Smith, 1853',
#  'Brullé, 1832',
#  'Pérez, 1895',
#  'LaBerge, 1967',
#  'Warncke, 1967',
#  'Linsley & MacSwain, 1961',
#  '(Viereck, 1904)',
#  'Morawitz, 1876',
#  '(Kirby, 1802)',
#  'Morawitz, 1877',
#  'Erichson, 1835',
#  'Warncke, 1975',
#  'Schmiedeknecht, 1883',
#  'Warncke, 1975',
#  'Warncke, 1965',
#  'Xu & Tadauchi, 2000',
#  'Cockerell, 1906',
#  'Warncke, 1965',
#  'Warncke, 1975',
#  'Patiny, 1998',
#  'Friese, 1922',
#  'van der Vecht, 1927',
#  'Morawitz, 1880',
#  'Robertson, 1891',
#  'Viereck, 1924',
#  'Tadauchi & Xu, 2002',
#  'Alfken, 1935',
#  'Warncke, 1975',
#  'Warncke, 1969',
#  'Warncke, 1965',
#  'Osytshnjuk, 1993',
#  '(Cockerell, 1938)',
#  'Tadauchi & Xu, 2002',
#  'Warncke, 1975',
#  'Ribble, 1974',
#  'Tadauchi & Matsumura, 2007',
#  'Warncke, 1974',
#  'Cameron, 1897',
#  'Warncke, 1965',
#  'Pérez, 1903',
#  'Tadauchi & Xu, 2002',
#  'Pérez, 1902',
#  'Imhoff, 1832',
#  'Warncke, 1974',
#  'Donovan, 1977',
#  'Warncke, 1975',
#  'Dours, 1872',
#  'Alfken, 1936',
#  'Grünwaldt, 1976',
#  'Osytshnjuk, 1975',
#  'Warncke, 1980',
#  'Warncke, 1975',
#  'Tadauchi & Xu, 2002',
#  'Lebedev, 1932',
#  'Warncke, 1969',
#  '(Fabricius, 1781)',
#  'Smith, 1869',
#  'Dunning, 1898',
#  'LaBerge & Ribble, 1975',
#  'Tadauchi, 1985',
#  'LaBerge, 1986',
#  '(Fabricius, 1775)',
#  'Viereck & Cockerell, 1914',
#  'Pérez, 1905',
#  'Jaeger, 1934',
#  'Tadauchi & Xu, 2002',
#  'Grünwaldt, 2005',
#  'Dubitzky, 2006',
#  'Warncke, 1965',
#  'Robertson, 1891',
#  'Viereck & Cockerell, 1914',
#  'Friese, 1899',
#  '(Linnaeus, 1758)',
#  'Viereck, 1904',
#  'Warncke, 1975',
#  'Nurse, 1904',
#  'Robertson, 1897',
#  'Ribble, 1968',
#  'Smith, 1853',
#  'Cockerell, 1922',
#  'Warncke, 1975',
#  'Cockerell, 1925',
#  'Morawitz, 1876',
#  'Hirashima, 1957',
#  'Smith, 1853',
#  'Warncke, 1968',
#  'Wu, 1982',
#  'Tadauchi & Matsumura, 2007',
#  'Robertson, 1895',
#  'Tadauchi, 1985',
#  'Cockerell, 1936',
#  'Provancher, 1888',
#  'Pérez, 1895',
#  'Warncke, 1967',
#  'Strand, 1915',
#  'Hirashima, 1962',
#  'Cockerell, 1949',
#  'Warncke, 1975',
#  'Warncke, 1965',
#  'Imhoff, 1832',
#  'Scheuchl, 2005',
#  'Wu, 1977',
#  'Friese, 1887',
#  'Lanham, 1949',
#  'Mavromoustakis, 1958',
#  'Warncke, 1975',
#  'Warncke, 1973',
#  'Cockerell, 1939',
#  'Schmiedeknecht, 1884',
#  'Schmiedeknecht, 1883',
#  'Warncke, 1974',
#  'LaBerge, 1967',
#  'Warncke, 1969',
#  'Mitchell, 1960',
#  'Bouseman & LaBerge, 1979',
#  'Robertson, 1891',
#  'LaBerge, 1977',
#  'Warncke, 1975',
#  'Cresson, 1872',
#  'Warncke, 1975',
#  'LaBerge, 1987',
#  'Kirby, 1837',
#  'Pérez, 1895',
#  'Cockerell, 1923',
#  'Eversmann, 1852',
#  'Viereck, 1916',
#  'Warncke, 1975',
#  'Morawitz, 1877',
#  'LaBerge, 1967',
#  'Morawitz, 1895',
#  'Morawitz, 1876',
#  'Morawitz, 1876',
#  'Gribodo, 1894',
#  'Warncke, 1974',
#  'Smith, 1853',
#  'Thomson, 1870',
#  'Popov, 1940',
#  'LaBerge, 1967',
#  'Warncke, 1969',
#  'Hirashima, 1953',
#  'Ribble, 1968',
#  'Hirashima, 1958',
#  'Schmiedeknecht, 1900',
#  'Timberlake, 1951',
#  'Warncke, 1965',
#  'Morawitz, 1894',
#  'Warncke, 1974',
#  'Warncke, 1975',
#  '(Smith, 1873)',
#  'Pohl & Larkin, 2006',
#  'Yasumatsu, 1935',
#  'Viereck, 1917',
#  'Cockerell, 1896',
#  'Morawitz, 1877',
#  'Hirashima, 1965',
#  'Ribble, 1974',
#  'Atwood, 1934',
#  'Schmiedeknecht, 1900',
#  'Hirashima, 1963',
#  'Friese, 1914',
#  'Alfken, 1936',
#  'Tadauchi & Matsumura, 2007',
#  'Hirashima, 1965',
#  'Osytshnjuk, 1986',
#  'Osytshnjuk, 1995',
#  'Osytshnjuk, 1995',
#  'Osytshnjuk, 1993',
#  'Warncke, 1969',
#  'Hedicke, 1940',
#  'Osytshnjuk, 1994',
#  'Yasumatsu, 1935',
#  'Alfken, 1900',
#  'Cockerell, 1901',
#  'Hirashima, 1952',
#  'Hirashima, 1965',
#  'Radoszkowski, 1886',
#  'Osytshnjuk, 1982',
#  'Warncke, 1975',
#  'Osytshnjuk, 1993',
#  'Grünwaldt, 2005',
#  'Hirashima, 1952',
#  'Friese, 1887',
#  'Mavromoustakis, 1954',
#  'Osytshnjuk, 1986',
#  'Osytshnjuk, 1994',
#  'Gusenleitner, 1998',
#  'Michener, 1954',
#  'Schmiedeknecht, 1883',
#  'Robertson, 1901',
#  'Lanham, 1983',
#  'Osytshnjuk, 1993',
#  'Cockerell, 1924',
#  'Tadauchi & Matsumura, 2007',
#  'Warncke, 1975',
#  'Ribble, 1968',
#  'Gusenleitner, 1998',
#  '(Kirby, 1802)',
#  'Fabricius, 1781',
#  'Osytshnjuk, 1993',
#  'Osytshnjuk, 1983',
#  'Morawitz, 1876',
#  'Warncke, 1974',
#  'Latreille, 1809',
#  'Ribble, 1968',
#  'Warncke, 1965',
#  'Viereck & Cockerell, 1914',
#  'Warncke, 1965',
#  'LaBerge, 1980',
#  'Zetterstedt, 1838',
#  'Morawitz, 1876',
#  'Alfken, 1899',
#  'Osytshnjuk, 1985',
#  'Morawitz, 1877',
#  'LaBerge, 1977',
#  'Wu, 1982',
#  'Donovan, 1977',
#  'Timberlake, 1951',
#  'Robertson, 1897',
#  'Warncke, 1974',
#  'LaBerge, 1977',
#  'Viereck & Cockerell, 1914',
#  'Timberlake, 1951',
#  'Osytshnjuk, 1995',
#  'Cameron, 1907',
#  'Schönitzer, 1997',
#  'Nurse, 1904',
#  'Schönitzer, 1997',
#  'Schenck, 1861',
#  'Ribble, 1968',
#  'Pérez, 1895',
#  'Warncke, 1974',
#  'Pérez, 1895',
#  'Xu & Tadauchi, 1995',
#  'Pérez, 1895',
#  'Hedicke, 1940',
#  'Thorp & LaBerge, 2005',
#  'Lepeletier, 1841',
#  'Warncke, 1967',
#  'Morawitz, 1876',
#  'Warncke, 1974',
#  'LaBerge, 1967',
#  'LaBerge, 1967',
#  'Thorp, 1969',
#  'Wu, 1992',
#  'Viereck, 1924',
#  'Mavromoustakis, 1948',
#  'Smith, 1853',
#  'LaBerge, 1967',
#  'Eversmann, 1852',
#  'Osytshnjuk, 1983',
#  'Pittioni, 1950',
#  'Warncke, 1968',
#  'Thorp, 1987',
#  'Timberlake, 1937',
#  'Pérez, 1895',
#  'LaBerge, 1977',
#  'Ribble, 1974',
#  'Pérez, 1895',
#  'Morawitz, 1895',
#  'LaBerge, 1977',
#  'Hirashima, 1962',
#  'Warncke, 1973',
#  'Tadauchi & Hirashima, 1988',
#  'Morawitz, 1876',
#  'Warncke, 1974',
#  'Warncke, 1975',
#  'Cockerell, 1906',
#  'Strand, 1915',
#  'Warncke, 1975',
#  'Warncke, 1967',
#  'Donovan, 1977',
#  'Cockerell, 1937',
#  'Robertson, 1900',
#  'Mitchell, 1951',
#  'Cockerell, 1916',
#  '(Matsumura, 1912)',
#  'Warncke, 1974',
#  'Linsley, 1960',
#  'Morawitz, 1876',
#  'Cockerell, 1922',
#  'Hirashima, 1964',
#  'Warncke, 1965',
#  'Kim & Kim, 1989',
#  'Warncke, 1965',
#  'Scheuchl & Gusenleitner, 2007',
#  'Morawitz, 1876',
#  'Thorp, 1969',
#  'Tadauchi & Hirashima, 1987',
#  'Gusenleitner & Schwarz, 2000',
#  'Robertson, 1892',
#  'Wu, 1982',
#  '(Fox, 1894)',
#  'Warncke, 1974',
#  'Fabricius, 1776',
#  'Robertson, 1891',
#  'Warncke, 1968',
#  'Viereck, 1917',
#  'Schmiedeknecht, 1900',
#  'Matsumura, 1911',
#  'Pérez, 1895',
#  '(Radoszkowski, 1891)',
#  'Cockerell, 1931',
#  'Cockerell, 1902',
#  'Pérez, 1895',
#  'Warncke, 1967',
#  'Pérez, 1895',
#  'Cockerell, 1898',
#  'Cockerell, 1918',
#  'Warncke, 1975',
#  'Warncke, 1966',
#  'Friese, 1899',
#  'Cresson, 1868',
#  'Cresson, 1872',
#  'Mitchell, 1960',
#  'Cockerell, 1897',
#  'Cameron, 1897',
#  'Saunders, 1908',
#  'Friese, 1922',
#  'Cockerell, 1901',
#  'Warncke, 1969',
#  'Cockerell, 1896',
#  'Cockerell, 1924',
#  'Cockerell, 1906',
#  'Tadauchi & Xu, 2003',
#  'Xu & Tadauchi, 2001',
#  'LaBerge, 1967',
#  'Ribble, 1968',
#  'LaBerge, 1978',
#  'Gusenleitner & Schwarz, 2000',
#  'Pérez, 1895',
#  'Cockerell, 1922',
#  'Pérez, 1895',
#  'Dours, 1873',
#  'Strand & Yasumatsu, 1938',
#  'Osytshnjuk, 1982',
#  'Graenicher, 1903',
#  'Larkin, 2004',
#  'Cockerell, 1929',
#  'Gribodo, 1894',
#  'LaBerge, 1986',
#  'Warncke, 1974',
#  '(Radoszkowski, 1891)',
#  'Osytshnjuk, 1995',
#  '(Kirby, 1802)',
#  'Perkins, 1914',
#  'Smith, 1879',
#  'Osytshnjuk, 1993',
#  'Timberlake, 1951',
#  'Cresson, 1872',
#  'Grünwaldt, 2005',
#  'Hirashima, 1963',
#  'Schmiedeknecht, 1883',
#  'Hirashima, 1964',
#  'Schmiedeknecht, 1884',
#  'Ribble, 1974',
#  'Linsley & MacSwain, 1955',
#  'Warncke, 1975',
#  'Warncke, 1965',
#  'Morawitz, 1880',
#  'Warncke, 1967',
#  'Cockerell, 1896',
#  'LaBerge, 1980',
#  'Viereck, 1917',
#  'Warncke, 1973',
#  'Osytshnjuk, 1986',
#  'Warncke, 1975',
#  'LaBerge, 1967',
#  'Viereck & Cockerell, 1914',
#  'Viereck & Cockerell, 1914',
#  'Morawitz, 1876',
#  'Friese, 1899',
#  'Warncke, 1975',
#  'Brullé, 1832',
#  'Cameron, 1897',
#  'Viereck, 1917',
#  'Kriechbaumer, 1873',
#  'Morawitz, 1876',
#  'Morawitz, 1871',
#  'Tadauchi, 1985',
#  'Warncke, 1967',
#  'Ribble, 1968',
#  'Cockerell, 1923',
#  'Warncke, 1965',
#  'Gusenleitner, 1998',
#  'Osytshnjuk, 1986',
#  'Warncke, 1975',
#  '(Kirby, 1802)',
#  'Noskiewicz, 1925',
#  'Popov, 1940',
#  'Dubitzky, 2006',
#  'Nylander, 1848',
#  'Lebedev, 1933',
#  'Strand, 1913',
#  'Robertson, 1895',
#  'Giraud, 1863',
#  'Osytshnjuk, 1984',
#  'Cockerell, 1913',
#  'Warncke, 1975',
#  'Larkin, 2004',
#  'Gusenleitner & Scheuchl, 2000',
#  'Ribble, 1968',
#  'Mavromoustakis, 1956',
#  'LaBerge, 1967',
#  'Viereck, 1917',
#  'Grünwaldt, 2005',
#  'Osytshnjuk, 1982',
#  'Osytshnjuk, 1993',
#  'Linsley & MacSwain, 1961',
#  '(Cresson, 1879)',
#  'Mitchell, 1960',
#  'Casad, 1896',
#  'Provancher, 1895',
#  'Robertson, 1905',
#  '(Kirby, 1802)',
#  'LaBerge & Bouseman, 1977',
#  '(Ashmead, 1890)',
#  'Provancher, 1895',
#  'Cockerell, 1906',
#  '(Kirby, 1802)',
#  'Cockerell, 1897',
#  'Linsley, 1939',
#  'Saunders, 1908',
#  'Dours, 1873',
#  'Dours, 1873',
#  'Warncke, 1967',
#  'Tadauchi & Hirashima, 1983',
#  'Warncke, 1969',
#  '(Müller, 1776)',
#  'Morawitz, 1876',
#  'Pérez, 1895',
#  'Schenck, 1853',
#  'Pérez, 1903',
#  'Smith, 1853',
#  'Friese, 1887',
#  'Xu & Tadauchi, 1999',
#  'Nurse, 1904',
#  'Morawitz, 1874',
#  '(Cockerell, 1905)',
#  'Robertson, 1897',
#  'Cockerell, 1933',
#  'Popov, 1940',
#  'Smith, 1853',
#  'Warncke, 1975',
#  'Warncke, 1973',
#  'Robertson, 1891',
#  'Yasumatsu, 1935',
#  'Lepeletier, 1841',
#  'Morawitz, 1876',
#  'Pérez, 1902',
#  'Imhoff, 1868',
#  'Warncke, 1967',
#  'Smith, 1853',
#  'Viereck, 1916',
#  'Warncke, 1974',
#  'Warncke, 1975',
#  'Warncke, 1975',
#  'Timberlake, 1937',
#  'LaBerge, 1967',
#  'Hirashima, 1957',
#  'Matsumura & Uchida, 1926',
#  'Viereck, 1916',
#  'Grünwaldt, 2005',
#  'Viereck, 1917',
#  'Hirashima, 1953',
#  '(Viereck, 1904)',
#  'Hirashima, 1952',
#  'Wu, 1982',
#  'LaBerge, 1967',
#  'Morawitz, 1876',
#  'Warncke, 1975',
#  'Morawitz, 1871',
#  'Scheuchl, 2005',
#  'Osytshnjuk, 1986',
#  'Warncke, 1965',
#  'Strand, 1917',
#  'Morawitz, 1866',
#  'Cockerell, 1936',
#  'Cockerell, 1916',
#  'Osytshnjuk, 1977',
#  'Tadauchi & Xu, 2000',
#  'Radoszkowski, 1867',
#  'Warncke, 1974',
#  '(Kirby, 1802)',
#  'Pérez, 1895',
#  'Donovan, 1977',
#  'Viereck & Cockerell, 1914',
#  'Warncke, 1965',
#  'Warncke, 1975',
#  'Brullé, 1832',
#  '(Viereck, 1904)',
#  '(Viereck, 1904)',
#  'Pérez, 1903',
#  'Timberlake, 1951',
#  'Warncke, 1974',
#  'Pérez, 1895',
#  'Warncke, 1968',
#  'Osytshnjuk, 1984',
#  'Morawitz, 1876',
#  'Mavromoustakis, 1957',
#  'De Stefani, 1887',
#  'Viereck & Cockerell, 1914',
#  'Viereck, 1917',
#  'Warncke, 1975',
#  ...]

# %%
import csv
import re
auth = []
with open('bee_list.txt', 'r') as bee:
    data = csv.DictReader(bee, delimiter='\t')
    header = data.fieldnames
    for row in data:
        auth.append(row['Taxon Author'])
        
    author = str(auth).replace("(","")
    author1 = str(author).replace(")","")
    author2 = str(author1).replace(" &",",")
    author3 = str(author2).replace("'","")
    author4 = re.sub(r'[\s\d]','',author3)
    author5 = str(author4).split(',')
    
from collections import defaultdict
count=defaultdict(int)
for a in author5:
    count[a] +=1
count

#Cockerell has the highest count
# Out:
# defaultdict(int,
#             {'[Michener': 1,
#              '': 19507,
#              'Cockerell': 3394,
#              'Timberlake': 864,
#              'Zavortink': 7,
#              'Dours': 62,
#              'Eversmann': 41,
#              'Pérez': 309,
#              'Warncke': 507,
#              'Hirashima': 210,
#              'Viereck': 130,
#              'Morawitz': 513,
#              'LaBerge': 192,
#              'Friese': 1330,
#              'Smith': 943,
#              'Scopoli': 8,
#              'Thorp': 19,
#              'Osytshnjuk': 74,
#              'Tadauchi': 76,
#              'Matsumura': 19,
#              'Popov': 86,
#              'Alfken': 149,
#              'Radoszkowski': 113,
#              'Rossi': 11,
#              'Perkins': 65,
#              'Robertson': 135,
#              'Benoist': 164,
#              'Miyanaga': 2,
#              'Dawut': 1,
#              'Lebedev': 9,
#              'Stoeckhert': 10,
#              'Linsley': 59,
#              'MacSwain': 16,
#              'Cresson': 437,
#              'Kirby': 74,
#              'Ribble': 31,
#              'Cameron': 158,
#              'Blüthgen': 315,
#              'Kreichbaumer': 1,
#              'Scheuchl': 10,
#              'Gusenleitner': 39,
#              'Schmiedeknecht': 50,
#              'Mitchell': 270,
#              'Hedicke': 24,
#              'Xu': 37,
#              'Donovan': 24,
#              'Nurse': 53,
#              'Malloch': 3,
#              'Bouseman': 8,
#              'Panzer': 29,
#              'Schulthess': 1,
#              'Fabricius': 138,
#              'Vachal': 557,
#              'Larkin': 6,
#              'Stephens': 1,
#              'Bingham': 47,
#              'Wu': 213,
#              'DallaTorre': 65,
#              'Strand': 249,
#              'Casad': 7,
#              'Pittioni': 7,
#              'Brullé': 33,
#              'Neff': 5,
#              'Yasumatsu': 53,
#              'Dubitzky': 12,
#              'Baker': 44,
#              'Schenck': 41,
#              'Linnaeus': 39,
#              'Christ': 4,
#              'Lepeletier': 185,
#              'Schwarz': 170,
#              'Theunert': 1,
#              'Morice': 11,
#              'Thomson': 9,
#              'Gribodo': 75,
#              'Mavromoustakis': 100,
#              'Erichson': 23,
#              'Provancher': 25,
#              'Lanham': 4,
#              'Dufour': 4,
#              'Kohl': 18,
#              'Haneda': 1,
#              'Giraud': 12,
#              'Grünwaldt': 7,
#              'Guiglia': 2,
#              'Ashmead': 30,
#              'Magretti': 18,
#              'Müller': 4,
#              'Patiny': 24,
#              'vanderVecht': 12,
#              'Imhoff': 8,
#              'Dunning': 3,
#              'Jaeger': 1,
#              'Pohl': 1,
#              'Atwood': 6,
#              'Michener': 454,
#              'Latreille': 35,
#              'Zetterstedt': 5,
#              'Schönitzer': 2,
#              'Kim': 2,
#              'Fox': 25,
#              'Saunders': 22,
#              'Graenicher': 9,
#              'Kriechbaumer': 7,
#              'Noskiewicz': 75,
#              'Nylander': 37,
#              'Uchida': 3,
#              'DeStefani': 1,
#              'Schwenninger': 1,
#              'Engel': 89,
#              'Spinola': 108,
#              'Hazir': 1,
#              'Illiger': 9,
#              'Tamasana': 1,
#              'Meunier': 5,
#              'Ducke': 92,
#              'Hurd': 36,
#              'Schuberth': 1,
#              'Rozen': 42,
#              'Moure': 417,
#              'Urban': 282,
#              'Gerstäcker': 55,
#              'Ascher': 1,
#              'Griswold': 50,
#              'Klug': 35,
#              'Sichel': 22,
#              'Graf': 2,
#              'Seabra': 12,
#              'Compagnucci': 10,
#              'Shinn': 25,
#              'Gonzalez': 19,
#              'Holmberg': 181,
#              'Fowler': 7,
#              'Jörgensen': 38,
#              'Porter': 4,
#              'Swenk': 62,
#              'Crawford': 88,
#              'Ruz': 45,
#              'Brèthes': 42,
#              'Toro': 140,
#              'Herrera': 3,
#              'Cure': 11,
#              'Wittman': 1,
#              'Roig-Alsina': 71,
#              'Rodríguez': 3,
#              'Walker': 112,
#              'Eardley': 93,
#              'Brauns': 35,
#              'Schwammberger': 8,
#              'Mocsáry': 67,
#              'Lucas': 9,
#              'Aurivillius': 1,
#              'Richards': 7,
#              'Ortiz-Sánchez': 1,
#              'Michez': 14,
#              'Snelling': 72,
#              'Danforth': 4,
#              'Parker': 15,
#              'Say': 35,
#              'Stevens': 4,
#              'Schrottky': 246,
#              'Melo': 23,
#              'Tapia': 4,
#              'Vivallo': 3,
#              'Reed': 5,
#              'Ramos': 1,
#              'LucasdeOliveira': 1,
#              'Schlindwein': 15,
#              'Chiappa': 3,
#              'Rayment': 209,
#              'Saussure': 28,
#              'Schulz': 13,
#              'Lieftinck': 108,
#              'Gussakovsky': 14,
#              'Priesner': 20,
#              'Brooks': 103,
#              'Pauly': 175,
#              'Buysson': 6,
#              'Meade-Waldo': 45,
#              'Fedtschenko': 29,
#              'W.F.Kirby': 13,
#              'deVillers': 1,
#              'Mariskovskaya': 1,
#              'Olivier': 14,
#              'Huard': 2,
#              'Pallas': 4,
#              'Banaszak': 1,
#              'Tkalcu': 86,
#              'Laboulbene': 1,
#              'Packard': 8,
#              'Westrich': 3,
#              'Romankova': 4,
#              'Stadelmann': 5,
#              'Enderlein': 19,
#              'Skorikov': 22,
#              'Franklin': 7,
#              'Dahlbom': 2,
#              'Vogt': 5,
#              'Seidl': 1,
#              'Handlirsch': 8,
#              'Frison': 13,
#              'Wahlberg': 1,
#              'Wang': 1,
#              'Guérin-Méneville': 19,
#              'Milliron': 1,
#              'DeGeer': 7,
#              'Bischoff': 10,
#              'Greene': 3,
#              'Schönherr': 1,
#              'Labougle': 1,
#              'Ayala': 22,
#              'Swederus': 2,
#              'Sladen': 3,
#              'Sparre-Schneider': 1,
#              'Schulthess-Rechberg': 1,
#              'Curtis': 4,
#              'Vollenhoven': 1,
#              'Geoffroy': 2,
#              'Herbst': 11,
#              'Blanchard': 4,
#              'Jensen-Haarup': 2,
#              'Azevedo': 2,
#              'Silveira': 7,
#              'Perty': 5,
#              'Burmeister': 5,
#              'Westwood': 11,
#              'Ruiz': 16,
#              'Oliveira': 8,
#              'Viana': 2,
#              'Zanella': 4,
#              'Castro': 1,
#              'Audinet-Serville': 11,
#              'Rodriguez': 2,
#              'Haliday': 7,
#              'Thiele': 1,
#              'Romand': 1,
#              'Bertoni': 7,
#              'Sitdikov': 5,
#              'Risch': 23,
#              'DusmetyAlonso': 33,
#              'Fonscolombe': 3,
#              'Bradley': 1,
#              'Bär': 1,
#              'Dover': 3,
#              'deGaulle': 1,
#              'Ogloblin': 7,
#              'Lovell': 17,
#              'Krombein': 11,
#              'Tucker': 1,
#              'Genaro': 16,
#              'Germar': 2,
#              'Kimsey': 10,
#              'Neves': 1,
#              'Nemésio': 5,
#              'González': 3,
#              'Gaiani': 3,
#              'Hoffmannsegg': 1,
#              'Dressler': 36,
#              'Sakagami': 38,
#              'Cheesman': 30,
#              'Hinojosa-Díaz': 8,
#              'Rebêlo': 5,
#              'Roubik': 13,
#              'Bembé': 1,
#              'Ramírez': 2,
#              'Rasmussen': 1,
#              'Skov': 1,
#              'Ospina-Torres': 2,
#              'Sandino-Franco': 1,
#              'Anjos-Silva': 1,
#              'González-Vaquero': 3,
#              'Almeida': 6,
#              'Rojas': 11,
#              'Taschenberg': 2,
#              'Forster': 1,
#              'Rightmyer': 40,
#              'Meyer': 31,
#              'Mackie': 2,
#              'deBeaumont': 1,
#              'Sivik': 1,
#              'Darchen': 2,
#              'Camargo': 75,
#              'Inoue': 3,
#              'Sepúlveda': 1,
#              'Marchi': 9,
#              'Jobiraj': 1,
#              'Narendran': 1,
#              'Bennett': 1,
#              'Kerr': 3,
#              'LoboSegura': 1,
#              'Vélez': 1,
#              'Pedro': 25,
#              'Wille': 3,
#              'Puls': 1,
#              'Silvestri': 2,
#              'Franck': 1,
#              'Boongird': 1,
#              'Albuquerque': 8,
#              'Shanks': 15,
#              'Shrottky': 1,
#              'Dominique': 2,
#              'Harter-Marques': 2,
#              'Cunha': 1,
#              'Truylio': 1,
#              'Heinrich': 3,
#              'Jurine': 4,
#              'Kocourek': 4,
#              'Hicks': 2,
#              'Cooper': 3,
#              'Proshchalykin': 1,
#              'Lelej': 2,
#              'Ehrenfeld': 3,
#              'Sandhouse': 78,
#              'Schilling': 1,
#              'GiordaniSoika': 1,
#              'Brues': 2,
#              'Tsuneki': 74,
#              'Lozinski': 2,
#              'Herrich-Schäffer': 8,
#              'Mazzucco': 1,
#              'Standfuss': 4,
#              'Benzi': 1,
#              'Moalif': 4,
#              'Broemeling': 5,
#              'Mitai': 3,
#              'Linné': 3,
#              'Evans': 4,
#              'Noble': 1,
#              'Rodeck': 1,
#              'Gmelin': 1,
#              'Arnold': 1,
#              'Ikudome': 8,
#              'Reyes': 21,
#              'Borges': 1,
#              'Syed': 2,
#              'Masi': 1,
#              'Houston': 50,
#              'Tierney': 1,
#              'H.S.Smith': 7,
#              'Kokujev': 1,
#              'Daly': 31,
#              'Chevrier': 1,
#              'Terzo': 12,
#              'Rasmont': 4,
#              'S.Lee': 1,
#              'Shiokawa': 4,
#              'Sickmann': 1,
#              'Sonan': 1,
#              'Maa': 22,
#              'Ritsema': 16,
#              'Maidl': 16,
#              'Vecht': 1,
#              'LeVeque': 10,
#              'Drury': 2,
#              'Leys': 2,
#              'Wiedemann': 1,
#              'Ponomareva': 2,
#              'Guilding': 1,
#              'Patton': 5,
#              'TruccoAleman': 5,
#              'Maynard': 16,
#              'Kuhlmann': 65,
#              'Stephen': 12,
#              'Janvier': 2,
#              'Metz': 16,
#              'Ortiz': 1,
#              'Ornosa': 1,
#              'Fourcroy': 1,
#              'Verhoeff': 1,
#              'Schmidt': 1,
#              'Raw': 7,
#              'Gistel': 3,
#              'Titus': 10,
#              'Frey-Gessner': 1,
#              'Dubitzki': 1,
#              'Packer': 29,
#              'Cabezas': 15,
#              'Davies': 11,
#              'Vergara': 1,
#              'Deyrup': 1,
#              'Roberts': 32,
#              'Exley': 231,
#              'Cardale': 1,
#              'Bridwell': 16,
#              'Dathe': 38,
#              'Magnacca': 10,
#              'Erlandsson': 1,
#              'Förster': 21,
#              'Blackburn': 3,
#              'Hensen': 1,
#              'Motschulski': 1,
#              'Gorski': 1,
#              'Sumner': 1,
#              'Abe': 1,
#              'Moldenke': 37,
#              'Gibbs': 1,
#              'Philippi': 2,
#              'Willis': 3,
#              'Smith-Pardo': 10,
#              'Eickwort': 7,
#              'Coelho': 5,
#              'Ordway': 3,
#              'Doering': 1,
#              'Yanega': 6,
#              'Klein': 2,
#              'E.A.B.Almeida': 5,
#              'Gonçalves': 4,
#              'Wolcott': 1,
#              'M.C.deAlmeida': 1,
#              'Laroca': 1,
#              'Ebmer': 215,
#              'Walckenaer': 1,
#              'Fan': 13,
#              'Bramson': 1,
#              'Pesenko': 56,
#              'Niu': 1,
#              'Huang': 1,
#              'Janjic': 1,
#              'McGinley': 24,
#              'Munakata': 1,
#              'Svensson': 1,
#              'Ellis': 23,
#              'Murao': 4,
#              'Munzinger': 2,
#              'Knerer': 5,
#              'Yáñez-Ordóñez': 3,
#              'Bytinski-Salz': 1,
#              'Wcislo': 3,
#              'Timmermann': 1,
#              'Takahashi': 1,
#              'Schrank': 2,
#              'Maeta': 9,
#              'Herrmann': 1,
#              'Davydova': 1,
#              'Godínez-García': 1,
#              'Stage': 4,
#              'Nobile': 7,
#              'Turrisi': 7,
#              'LaRoche': 3,
#              'Hagens': 10,
#              'R.P.Urban': 5,
#              'Wesmael': 1,
#              'Kato': 1,
#              'Itino': 1,
#              'Cross': 2,
#              'Wickwar': 1,
#              'Schletterer': 23,
#              'He': 2,
#              'Costa': 6,
#              'Astafurova': 2,
#              'Bohart': 47,
#              'Batra': 1,
#              'Whitehead': 16,
#              'Gupta': 16,
#              'Pasteels': 197,
#              'Simlote': 2,
#              'Perris': 4,
#              'Jaycox': 1,
#              'Rohwer': 2,
#              'Grigarick': 2,
#              'Stange': 3,
#              'Sharma': 6,
#              'Peters': 16,
#              'vanderZanden': 53,
#              'Rahman': 1,
#              'Tewari': 1,
#              'Sielfeld': 1,
#              'Schummel': 1,
#              'Fritz': 15,
#              'Hill': 1,
#              'Nagase': 3,
#              'Proschchalykin': 1,
#              'Dewitz': 1,
#              'King': 9,
#              'Rebmann': 18,
#              'Durante': 4,
#              'Schwimmer': 1,
#              'Schulten': 7,
#              'Ferton': 6,
#              'Abramovich': 2,
#              'Lucia': 2,
#              'Silveiraetal.': 1,
#              'Stanek': 5,
#              'LeGoff': 1,
#              'Teunissen': 1,
#              'vanAchterberg': 1,
#              'Rust': 3,
#              'Atanassov': 1,
#              'White': 4,
#              'Haeseler': 1,
#              'Robinaeau': 1,
#              'Dumeril': 1,
#              'vonSchulthess': 1,
#              'Harris': 1,
#              'Rudow': 2,
#              'Quilis': 2,
#              'Steiner': 13,
#              'Vogel': 1,
#              ']': 1})

# %% [markdown]
# # Cockerell has the highest count

# %%
string1="Tadauchi, Miyanaga & Dawut, 2005"
string2="(Linneus, 1758)"

def check(author_list):
    char = re.compile(r'[\,\&\(\)\d]')
    authors=[]
